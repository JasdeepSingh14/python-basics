# %% [markdown]
# # ***THEORY QUESTIONS***

# %% [markdown]
# ***`1. What is the difference between interpreted and compiled languages`***
#
#
# ***ANSWER-***
#
#
# Interpreted languages: Executed line by line by an interpreter e.g., Python.
#
# Compiled languages: Translated into machine code before execution e.g., C, C++.

# %% [markdown]
# ***`2. What is exception handling in Python`***
#
#
# ***ANSWER-***
# A mechanism to handle runtime errors gracefully using try, except, finally, else.

# %% [markdown]
# ***`3. What is the purpose of the finally block in exception handling`***
#
#
# ***ANSWER-***
#
# The finally block runs always, whether an exception occurs or not useful for cleanup like closing files.

# %% [markdown]
# ***`4. What is logging in Python`***
#
# ***ANSWER-***
#
# Logging provides a way to record messages, errors, and events from a program for debugging and monitoring.

# %% [markdown]
# ***`5. What is the significance of the __del__ method in Python`***
#
# ***ANSWER-***
#
# It is a destructor method, called automatically when an object is deleted or goes out of scope.

# %% [markdown]
# ***`6. What is the difference between import and from ... import in Python`***
#
# ***ANSWER-***
#
# import module- brings the whole module use with module.function.
#
# from module import func- imports specific functions/classes directly.
#
# ***`7. How can you handle multiple exceptions in Python`***
#
# ***ANSWER-***
#
# Eg-
#
# try:
#
#     x = int("abc")
#
# except ValueError:
#
#     print("Value error")
# except TypeError:
#
#     print("Type error")
#
#
# ***`8. What is the purpose of the with statement when handling files in Python`***
#
# ***ANSWER-***
#
# It ensures automatic closing of the file after use.
#
# with open("file.txt") as f:
#     data = f.read()
#
#
# ***`9. What is the difference between multithreading and multiprocessing`***
#
# ***ANSWER-***
#
# Multithreading: Multiple threads in one process, share memory good for I/O tasks.
#
# Multiprocessing: Multiple processes, each with separate memory good for CPU tasks.
#
# ***`10. What are the advantages of using logging in a program`***
#
# ***ANSWER-***
#
# 1. Helps in debugging
#
# 2. Stores errors for later analysis
#
# 3. Provides multiple levels (INFO, ERROR, WARNING)
#
# 4. Better than print statements
#
# ***`11. What is memory management in Python`***
#
# ***ANSWER-***
#
# It is the way Python allocates and manages memory for objects using automatic garbage collection.
#
# ***`12. What are the basic steps involved in exception handling in Python`***
#
# ***ANSWER-***
#
# 1. Write risky code in try.
#
# 2. Handle error with except.
#
# 3. Use else for code that runs if no error.
#
# 4. Use finally for cleanup code.
#
# ***`13. Why is memory management important in Python`***
#
# ***ANSWER-***
#
# Prevents memory leaks, optimizes performance, ensures efficient resource use.
#
# ***`14. What is the role of try and except in exception handling`***
#
# ***ANSWER-***
#
# try: Wraps risky code.
#
# except: Defines what to do if an exception occurs.
#
# ***`15. How does Python's garbage collection system work`***
#
# ***ANSWER-***
#
# Uses reference counting and cyclic garbage collector to free unused memory automatically.

# %% [markdown]
# ***`16. What is the purpose of the else block in exception handling`***
#
# ***ANSWER-***
#
# Runs code only if no exception occurs in the try block.

# %% [markdown]
# ***`17. What are the common logging levels in Python`***
#
#
# ***ANSWER-***
# DEBUG,
# INFO,
# WARNING,
# ERROR,
# CRITICAL

# %% [markdown]
# ***`18. What is the difference between os.fork() and multiprocessing in Python`***
#
#
# ***ANSWER-***
#
# os.fork(): Unix-only, creates a child process directly.
#
# multiprocessing: Cross-platform, higher-level API for creating processes.

# %% [markdown]
# ***`19. What is the importance of closing a file in Python`***
#
#
# ***ANSWER-***
#
# 1. Frees system resources
# 2. Ensures data is written properly to disk
# 3. Prevents memory leaks

# %% [markdown]
# ***`20. What is the difference between file.read() and file.readline() in Python`***
#
#
# ***ANSWER-***
#
# file.read() - Reads the entire file as a single string.
#
# file.readline() - Reads one line at a time.

# %% [markdown]
# ***`21. What is the logging module in Python used for`***
#
# ***ANSWER-***
#
# For recording messages errors, warnings, debug info into files or console with different levels.

# %% [markdown]
# ***`22. What is the os module in Python used for in file handling`***
#
# ***ANSWER-***
#
# Provides functions to interact with the operating system create/delete files, check paths, list directories.

# %% [markdown]
# ***`23. What are the challenges associated with memory management in Python`***
#
#
# ***ANSWER-***
#
# 1. Circular references between objects can delay garbage collection.
#
# 2. Large objects or datasets may lead to high memory usage.
#
# 3. Garbage collector overhead can affect performance.
#
# 4. Memory fragmentation can reduce efficiency.
#
# 5. Developers have less direct control compared to low-level languages like C/C++

# %% [markdown]
# ***`24. How do you raise an exception manually in Python`***
#
#
#
#
#
# ***ANSWER-***
#
# raise ValueError("This is a manual error")

# %% [markdown]
# ***`25. Why is it important to use multithreading in certain applications`***
#
#
# ***ANSWER-***
#
# Useful for tasks that are I/O bound e.g., network requests, file downloads.
# Improves responsiveness and efficiency.

# %% [markdown]
# # ***PRACTICAL QUESTIONS***

# %%
#1. How can you open a file for writing in Python and write a string to it

with open("file.txt", "w") as f:
  f.write("Hello, \n""My name is jas")

# %%
# 2. Write a Python program to read the contents of a file and print each line

with open("file.txt","r") as f:
    print(f.read())
# Out:
# Hello,
# My name is jas

# %%
#3. How would you handle a case where the file doesn't exist while trying to open it for reading

try:
  open("file1.txt","r")
except FileNotFoundError:
   print("Not found")
# Out:
# Not found

# %%
# 4. Write a Python script that reads from one file and writes its content to another file

with open("file.txt","r") as f:
  with open("test.txt", "w") as g:
    g.write(f.read())

# %%
# 5. How would you catch and handle division by zero error in Python

# by using try and except block
try:
  1/0
except ZeroDivisionError:
  print("Error")
# Out:
# Error

# %%
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs

import logging
logging.basicConfig(filename="error.log", level=logging.ERROR, format="%(asctime)s - %(levelname)s - %(message)s")

def divide_numbers(a, b):
    try:
        result = a / b
        print(f"Result: {result}")
    except ZeroDivisionError as e:
        logging.error("Division by zero error occurred: %s", e)
        print("Error: Division by zero! Check error.log for details.")


divide_numbers(10, 0)

# %%
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

import logging

logging.basicConfig(filename="app.log", level=logging.DEBUG, format="%(asctime)s - %(levelname)s - %(message)s")

# Logging at different levels
logging.info("This is an INFO message: The program started successfully.")
logging.warning("This is a WARNING message: Disk space is running low.")
logging.error("This is an ERROR message: Unable to connect to the database.")

# %%
# 8. Write a program to handle a file opening error using exception handling

try:
  open("hel.txt","r")
except Exception as e:
   print(e)
# Out:
# [Errno 2] No such file or directory: 'hel.txt'

# %%
# 9. How can you read a file line by line and store its content in a list in Python

with open("file.txt","r") as f:
  print(f.readlines())
# Out:
# ['Hello, \n', 'My name is jas']

# %%
# 10. How can you append data to an existing file in Python

with open("file.txt","a") as f:
   f.write(" Bonjour!")

# %%
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist

dic={"a":1}
try:
   print(dic["b"])
except KeyError:
  print("Key missing")
# Out:
# Key missing

# %%
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions

try:
   1/0
except ZeroDivisionError:
   print("Zero division")
except ValueError:
   print("Value error")
# Out:
# Zero division

# %%
#13. How would you check if a file exists before attempting to read it in Python

import os
if os.path.exists("file.txt"):
  print(open("file.txt").read())
# Out:
# Hello,
# My name is jas Bonjour!

# %%
#  14. Write a program that uses the logging module to log both informational and error messages

import logging
logging.basicConfig(level=logging.INFO)
logging.info("Info message")
logging.error("Error message")

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty

with open("file.txt") as f:
    c=f.read()
    print("Empty" if not c else c)
# Out:
# Hello,
# My name is jas Bonjour!

# %%
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program

# !pip install memory-profiler
from memory_profiler import profile

@profile
def my_func():
    nums = [i for i in range(10000)]
    print("List created")

my_func()

# %%
# 17. Write a Python program to create and write a list of numbers to a file, one number per line

nums=[1,2,3,4,5]
with open("nums.txt","w") as f:
    for n in nums:
      f.write(f"{n}\n")

# %%
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB

import logging
from logging.handlers import RotatingFileHandler
h=RotatingFileHandler("log.txt",maxBytes=1_000_000,backupCount=3)
logging.basicConfig(handlers=[h],level=logging.INFO)
logging.info("test")

# %%
# 19. Write a program that handles both IndexError and KeyError using a try-except block

try:
    mylist = [1, 2]
    print(mylist[5])   # IndexError
    mydict = {"a": 1}
    print(mydict["b"]) # KeyError
except IndexError:
    print("Index out of range")
except KeyError:
    print("Key not found")
# Out:
# Index out of range

# %%
# 20. How would you open a file and read its contents using a context manager in Python

with open("file.txt") as f:
  print(f.read())
# Out:
# Hello,
# My name is jas Bonjour!

# %%
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word

word="jas"
with open("file.txt") as f:
   print(f.read().split().count(word))
# Out:
# 1

# %%
#22. How can you check if a file is empty before attempting to read its contents

import os
if os.stat("file.txt").st_size==0:
   print("Empty")
else:
  with open("file.txt","r") as f:
        print(f.read(),"\n\n\n{file contains some content !}")
# Out:
# Hello,
# My name is jas Bonjour!
#
#
# {file contains some content !}

# %%
#23. Write a Python program that writes to a log file when an error occurs during file handling

import logging
logging.basicConfig(filename="log.txt",level=logging.ERROR)
try:
  open("nofile.txt")
except Exception as e:
  logging.error(str(e))
